# %% [markdown]
# ## String en python 'str'
#
# Metodos mas utilizados son:
# * len(string)
# * str.upper()
# * str.lower()
# * str.strip()
# * str.split()

# %% [markdown]
# ## 'int', ENTEROS

# %% [markdown]
# ## 'float', DECIMALES

# %% [markdown]
# ## 'bool', BOOLEANOS

# %% [markdown]
# ## NONE - representa el valor nulo
